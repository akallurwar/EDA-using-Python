# %%
import os

os.getcwd()
# Out:
# 'C:\\Users\\Yash\\Python my work\\My work\\Project Data\\HR Analytics'

# %% [markdown]
# - Attrition is a problem that impacts all businesses, irrespective of geography, industry and size of the company.
# Employee attrition leads to significant costs for a business, including the cost of business disruption, hiring new staff and training new staff.
#
# - As such, there is great business interest in understanding the drivers of, and minimizing staff attrition.
#
# - In this context, the use of classification models to predict if an employee is likely to quit could greatly
# increase the HR’s ability to intervene on time and remedy the situation to prevent attrition.
#
# - While this model can be routinely run to identify employees who are most likely to quit, the key driver of success would be the human element of
# reaching out the employee, understanding the current situation of the employee and taking action to remedy controllable factors that can prevent attrition of the employee.
#
# - This data set presents an employee survey from IBM, indicating if there is attrition or not. The data set contains approximately 1500 entries.
#
# - Given the limited size of the data set, the model should only be expected to provide modest improvement in indentification of attrition vs a random allocation of probability of attrition.
#
# - While some level of attrition in a company is inevitable, minimizing it and being prepared for the cases that cannot be helped will significantly help improve the operations of most businesses.
#
# - As a future development, with a sufficiently large data set, it would be used to run a segmentation on employees,
# to develop certain “at risk” categories of employees. This could generate new insights for the business on what drives attrition, insights that cannot be generated by merely informational interviews with employees.

# %% [markdown]
# Name	 			Description
#
# AGE				Numerical Value
#
# ATTRITION			Employee leaving the company (0=no, 1=yes)
#
# BUSINESS TRAVEL			(1=No Travel, 2=Travel Frequently, 3=Tavel Rarely)
#
# DAILY RATE			Numerical Value - Salary Level
#
# DEPARTMENT			(1=HR, 2=R&D, 3=Sales)
#
# DISTANCE FROM HOME		Numerical Value - THE DISTANCE FROM WORK TO HOME
#
# EDUCATION			Numerical Value
#
# EDUCATION FIELD			(1=HR, 2=LIFE SCIENCES, 3=MARKETING, 4=MEDICAL SCIENCES, 5=OTHERS, 6= TEHCNICAL)
#
# EMPLOYEE COUNT			Numerical Value
#
# EMPLOYEE NUMBER			Numerical Value - EMPLOYEE ID
#
# ENVIROMENT SATISFACTION		Numerical Value - SATISFACTION WITH THE ENVIROMENT
#
# GENDER				(1=FEMALE, 2=MALE)
#
# HOURLY RATE			Numerical Value - HOURLY SALARY
#
# JOB INVOLVEMENT			Numerical Value - JOB INVOLVEMENT
#
# JOB LEVEL			Numerical Value - LEVEL OF JOB
#
# JOB ROLE			(1=HC REP, 2=HR, 3=LAB TECHNICIAN, 4=MANAGER, 5= MANAGING DIRECTOR,6= REASEARCH DIRECTOR,
#
# 7= RESEARCH SCIENTIST, 8=SALES EXECUTIEVE, 9= SALES REPRESENTATIVE)
#
# JOB SATISFACTION		Numerical Value - SATISFACTION WITH THE JOB
#
# MARITAL STATUS			(1=DIVORCED, 2=MARRIED, 3=SINGLE)
#
# MONTHLY INCOME			Numerical Value - MONTHLY SALARY
#
# MONTHY RATE			Numerical Value - MONTHY RATE
#
# NUMCOMPANIES WORKED		Numerical Value - NO. OF COMPANIES WORKED AT
#
# OVER 18				(1=YES, 2=NO)
#
# OVERTIME			(1=NO, 2=YES)
#
# PERCENT SALARY HIKE		Numerical Value - PERCENTAGE INCREASE IN SALARY
#
# PERFORMANCE RATING		Numerical Value - ERFORMANCE RATING
#
# RELATIONS SATISFACTION		Numerical Value - RELATIONS SATISFACTION
#
# STANDARD HOURS			Numerical Value - STANDARD HOURS
#
# STOCK OPTIONS LEVEL		Numerical Value - STOCK OPTIONS
#
# TOTAL WORKING YEARS		Numerical Value - TOTAL YEARS WORKED
#
# TRAINING TIMES LAST YEAR	Numerical Value - HOURS SPENT TRAINING
#
# WORK LIFE BALANCE		Numerical Value - TIME SPENT BEWTWEEN WORK AND OUTSIDE
#
# YEARS AT COMPANY		Numerical Value - TOTAL NUMBER OF YEARS AT THE COMPNAY
#
# YEARS IN CURRENT ROLE		Numerical Value -YEARS IN CURRENT ROLE
#
# YEARS SINCE LAST PROMOTION	Numerical Value - LAST PROMOTION
#
# YEARS WITH CURRENT MANAGER	Numerical Value - YEARS SPENT WITH CURRENT MANAGER

# %% [markdown]
# ### Importing libraries

# %%
import numpy as np
import pandas as pd
import pandas_profiling
import seaborn as sns
# %matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
# ### Loading Dataset

# %%
df=pd.read_csv("C:\\Users\\Yash\\Python my work\\My work\\Project Data\\HR Analytics\\HR-Employee-Attrition.csv")
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# 5      32        No  Travel_Frequently       1005  Research & Development
# 6      59        No      Travel_Rarely       1324  Research & Development
# 7      30        No      Travel_Rarely       1358  Research & Development
# 8      38        No  Travel_Frequently        216  Research & Development
# 9      36        No      Travel_Rarely       1299  Research & Development
# 10     35        No      Travel_Rarely        809  Research & Development
# 11     29        No      Travel_Rarely        153  Research & Development
# ...

# %%
df.head()
# Out:
#    Age  Attrition     BusinessTravel  DailyRate              Department  \
# 0   41          1      Travel_Rarely       1102                   Sales
# 1   49          1  Travel_Frequently        279  Research & Development
# 2   37          1      Travel_Rarely       1373  Research & Development
# 3   33          1  Travel_Frequently       1392  Research & Development
# 4   27          1      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#             ...             StockOptionLevel  TotalWorkingYears  \
# ...

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
# Age                         1470 non-null int64
# Attrition                   1470 non-null object
# BusinessTravel              1470 non-null object
# DailyRate                   1470 non-null int64
# Department                  1470 non-null object
# DistanceFromHome            1470 non-null int64
# Education                   1470 non-null int64
# EducationField              1470 non-null object
# EmployeeCount               1470 non-null int64
# EmployeeNumber              1470 non-null int64
# EnvironmentSatisfaction     1470 non-null int64
# Gender                      1470 non-null object
# HourlyRate                  1470 non-null int64
# JobInvolvement              1470 non-null int64
# JobLevel                    1470 non-null int64
# JobRole                     1470 non-null object
# JobSatisfaction             1470 non-null int64
# ...

# %%
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %% [markdown]
# ### Pre_Profiling

# %%
profile = pandas_profiling.ProfileReport(df)
profile.to_file(outputfile="Attrition_before_preprocessing.html")
profile
# Out:
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
# ...

# %% [markdown]
# ### Data Manipulation

# %%
df["Attrition"]=df["Attrition"].apply(lambda x: 0 if x == 'No' else 1)

# %%
df["Age group"] = df.apply(lambda x: "Young" if x["Age"]<=35 else "Middle age",axis=1)

# %%
df["Gender"]=df["Gender"].apply(lambda x: 1 if x == "Female" else 2)

# %%
df["JobRole"]=df["JobRole"].apply(lambda x: 1 if x=="Healthcare Representative" else (2 if x=="Human Resources" else (3 if x == "Laboratory Technician" else (4 if x == "Manager" else (5 if x=="Manufacturing Director" else (6 if x== "Research Director" else (7 if x== "Research Scientist" else (8 if x=="Sales Executive" else (9 if x == "Sales Representative" else "none")))))))))

# %%
df["TotalWorkingYears_Group"] = df.apply(lambda x: "0-10" if x["TotalWorkingYears"]<=10 else ("10-20" if (x["TotalWorkingYears"]>10 and x["TotalWorkingYears"]<=20) else ("20-40" if (x["TotalWorkingYears"]>20 and x["TotalWorkingYears"]<=40) else "none")),axis=1)

# %% [markdown]
# ### Post_Profiling

# %%
profile = pandas_profiling.ProfileReport(df)
profile.to_file(outputfile="Attrition_after_preprocessing.html")
profile
# Out:
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
# ...

# %% [markdown]
# ### Questions

# %% [markdown]
# ####  1.What would be the "at risk" attrition rate as per survey?

# %%
df["Attrition"].value_counts()
# Out:
# 0    1233
# 1     237
# Name: Attrition, dtype: int64

# %%
df.groupby(["Attrition"])["Attrition"].count().plot.bar()

# %% [markdown]
# #### Observation
# - We can see from the graph that, the attrition rate in company would be 15%.

# %% [markdown]
# #### 2. Analyzing the attrition rate with respect to age

# %%
df["Age"].plot.hist(grid=True, bins=20,rwidth=0.5,color='#607c8e')

# %%
df["Age group"] = df.apply(lambda x: "Young" if x["Age"]<=35 else "Middle age",axis=1)

# %%
df.groupby(["Age group","Attrition"])["Attrition"].count()
# Out:
# Age group   Attrition
# Middle age  0            664
#             1             77
# Young       0            569
#             1            160
# Name: Attrition, dtype: int64

# %%
plt.figure(figsize=(8,4))
sns.countplot(x="Age group",hue="Attrition",data=df,order=["Young","Middle age"])
plt.show()

# %%
f,ax = plt.subplots(1,2,figsize=(10,5))
df['Attrition'][df['Age group'] == 'Young'].value_counts().plot.pie(explode=[0,0.2],autopct='%1.1f%%',ax=ax[0],shadow=True)
df['Attrition'][df['Age group'] == 'Middle age'].value_counts().plot.pie(explode=[0,0.2],autopct='%1.1f%%',ax=ax[1],shadow=True)
ax[0].set_title('Attrition (Young)')
ax[1].set_title('Attrition (Middle age)')
# Out:
# Text(0.5, 1.0, 'Attrition (Middle age)')

# %% [markdown]
# #### Observation
# - Mostly the attrition would be in young age group which is below 35 years.
# - Almost 22% attrition would be in young age group.

# %% [markdown]
# #### 3. Analyzing the attrition with respect to Age, Gender and Total working years

# %%
df.groupby(["TotalWorkingYears_Group","Age group","Attrition"])["Attrition"].count()
# Out:
# TotalWorkingYears_Group  Age group   Attrition
# 0-10                     Middle age  0            258
#                                      1             36
#                          Young       0            483
#                                      1            146
# 10-20                    Middle age  0            215
#                                      1             25
#                          Young       0             86
#                                      1             14
# 20-40                    Middle age  0            191
#                                      1             16
# Name: Attrition, dtype: int64

# %%
sns.catplot(x="Age group",y="TotalWorkingYears",hue="Attrition",col="Gender",kind="violin",data=df,order=["Young","Middle age"])
# Out:
# C:\Ankita\Anaconda\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# #### Observation
# - From the above graph,we can see that young employees have higher attrition rate than others.
# - Young employees with 0-10 years experience would have almost 23% attrition rate.

# %% [markdown]
# #### 4. How job level affects attrition?

# %%
df.groupby(["JobLevel","Attrition"])["Attrition"].count()
# Out:
# JobLevel  Attrition
# 1         0            400
#           1            143
# 2         0            482
#           1             52
# 3         0            186
#           1             32
# 4         0            101
#           1              5
# 5         0             64
#           1              5
# Name: Attrition, dtype: int64

# %%
sns.countplot(x="JobLevel",hue="Attrition",data=df)

# %% [markdown]
# ##### Analyzing the attrition with respect to job level & monthly income

# %%
sns.catplot(x="JobLevel",y="MonthlyIncome",hue="Attrition",kind="violin",data=df)

# %% [markdown]
# #### Observation:
# - Highest risk of attrition has seen in Job Level 1 and least in Job Level 4 & 5.
# - Almost 60% risk of attrition is in Job level 1.
# - We can also see that as the job level & monthly income increasing, risk of attrition getting decreased.

# %% [markdown]
# #### 5. How Job Role affecting attrition?

# %%
df["JobRole"]=df["JobRole"].apply(lambda x: 1 if x=="Healthcare Representative" else (2 if x=="Human Resources" else (3 if x == "Laboratory Technician" else (4 if x == "Manager" else (5 if x=="Manufacturing Director" else (6 if x== "Research Director" else (7 if x== "Research Scientist" else (8 if x=="Sales Executive" else (9 if x == "Sales Representative" else "none")))))))))

# %%
df.groupby(["JobRole","Attrition"])["Attrition"].count()
# Out:
# JobRole  Attrition
# none     0            1233
#          1             237
# Name: Attrition, dtype: int64

# %%
sns.countplot(x="JobRole",hue="Attrition",data=df)

# %% [markdown]
# #### Analyzing the risk of attrition with respect to Job Role & Monthly income

# %%
sns.catplot(x="JobRole",y="MonthlyIncome",hue="Attrition",kind="violin",data=df, height=5, aspect=2)
# Out:
# C:\Ankita\Anaconda\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# #### Observation:
# - From the above graph we can see that, as the hierachy getting higher the risk of attrition is getting lower.
# - We can see, maximum risk is in executive level roles with monthly income less than 10000 like Healthcare representative,Lab Technician, Sales executive, Sales representative etc
# - Very less risk of attrition in Manager & Director level roles with monthly income more than 15000.

# %% [markdown]
# #### 7. How Over time have a effect on attrition risk?

# %%
df.groupby(["OverTime","Attrition"])["Attrition"].count()
# Out:
# OverTime  Attrition
# No        0            944
#           1            110
# Yes       0            289
#           1            127
# Name: Attrition, dtype: int64

# %%
sns.countplot(x="OverTime",hue="Attrition",data=df)

# %% [markdown]
# #### Observation
# From the graph,we can see that
# - If employees are doint Overtime then the attrition risk is more.
# - If its a overtime then employees are at 30% risk of Attrition and if not then its only 10%.

# %% [markdown]
# #### 8. What is the effect of Marital status on attrition risk?

# %%
sns.countplot(x="MaritalStatus",hue="Attrition",data=df)

# %%
df.groupby(["MaritalStatus","Gender","Attrition"])["Attrition"].count()
# Out:
# MaritalStatus  Gender  Attrition
# Divorced       1       0            108
#                        1              9
#                2       0            186
#                        1             24
# Married        1       0            241
#                        1             31
#                2       0            348
#                        1             53
# Single         1       0            152
#                        1             47
#                2       0            198
#                        1             73
# Name: Attrition, dtype: int64

# %%
sns.catplot(x="MaritalStatus",y="Attrition",hue="Gender",kind="violin",data=df,height=5, aspect=1.5)

# %% [markdown]
# #### Observation
# From the above graph,
# - We can see that, the risk of attrition is high in Single employees.
# - And that too in single males,the attrition risk is slightly higher as compare to females.
# - Divorsed females have least attrition risk.

# %% [markdown]
# #### 9. Analyzing the risk of attrition with respect to Gender, Marital Status & Total work experience

# %%
sns.catplot(x="MaritalStatus",y="TotalWorkingYears",hue="Attrition",col="Gender",kind="box",data=df,height=6, aspect=1)

# %% [markdown]
# #### Observation
# From the above graph,
# - We can see that, Single males with experience 0-10 years have highest risk of attrition.
# - from the data we observed that, the attrition risk for single males & females are almost close to 25%.

# %% [markdown]
# #### 10. Which department has highest risk of attrition?

# %%
df.groupby(["Department","Attrition"])["Attrition"].count()
# Out:
# Department              Attrition
# Human Resources         0             51
#                         1             12
# Research & Development  0            828
#                         1            133
# Sales                   0            354
#                         1             92
# Name: Attrition, dtype: int64

# %%
plt.figure(figsize=(7,3))
sns.countplot(x="Department",hue="Attrition",data=df)
plt.show()

# %% [markdown]
# #### Observation
# - Sales department has highest risk of attrition which is 20%.

# %% [markdown]
# #### 11.How total working years affect risk of attrition?

# %%
df["TotalWorkingYears"].plot.hist(grid=True, bins=20,rwidth=0.5,color='#607c8e')

# %%
df["TotalWorkingYears"]=df["TotalWorkingYears"].apply(lambda x: "0-10" if x<=10 else ("10-20" if (x>10 and x<=20) else "20-40" if (x>20 and x<=40) else "none"))

# %%
df["TotalWorkingYears"].value_counts()
# Out:
# 0-10     923
# 10-20    340
# 20-40    207
# Name: TotalWorkingYears, dtype: int64

# %%
sns.countplot(x="TotalWorkingYears",hue="Attrition",data=df)

# %%
f,ax = plt.subplots(1,3,figsize=(10,5))
df['Attrition'][df['TotalWorkingYears'] == '0-10'].value_counts().plot.pie(explode=[0,0.2],autopct='%1.1f%%',ax=ax[0],shadow=True)
df['Attrition'][df['TotalWorkingYears'] == '10-20'].value_counts().plot.pie(explode=[0,0.2],autopct='%1.1f%%',ax=ax[1],shadow=True)
df['Attrition'][df['TotalWorkingYears'] == '20-40'].value_counts().plot.pie(explode=[0,0.2],autopct='%1.1f%%',ax=ax[2],shadow=True)
ax[0].set_title('Attrition (0-10 years)')
ax[1].set_title('Attrition (10-20 years)')
ax[2].set_title('Attrition (20-40 years)')
# Out:
# Text(0.5, 1.0, 'Attrition (20-40 years)')

# %%
df.groupby(["TotalWorkingYears_Group","JobLevel","Attrition"])["Attrition"].count()
# Out:
# TotalWorkingYears_Group  JobLevel  Attrition
# 0-10                     1         0            359
#                                    1            134
#                          2         0            310
#                                    1             36
#                          3         0             68
#                                    1             12
#                          4         0              4
# 10-20                    1         0             41
#                                    1              9
#                          2         0            172
#                                    1             16
#                          3         0             85
#                                    1             14
#                          4         0              3
# 20-40                    3         0             33
#                                    1              6
#                          4         0             94
# ...

# %%
sns.catplot(x="JobLevel",y="TotalWorkingYears",hue="Attrition",kind="violin",data=df)

# %%
sns.catplot(x="JobLevel",col="TotalWorkingYears",hue="Attrition",kind="count",ci=None,data=df)

# %% [markdown]
# #### Observations
# From the above graphs,
# - We can see that, attrition rate is high in employees with total 0-10 years experience.
# - Attrition rate is almost 20% in employees with less than 10 years experience.
# - High attrition in Job level 1 with 0-10 years experience.
# - Attrition rate in Job lvel 1 with 0-10 years experience is approximatly 25%.

# %%
sns.countplot(x="NumCompaniesWorked",hue="Attrition",data=df)

# %%
df.groupby(["TotalWorkingYears","NumCompaniesWorked","Attrition"])["Attrition"].count()
# Out:
# TotalWorkingYears  NumCompaniesWorked  Attrition
# 0-10               0                   0            131
#                                        1             20
#                    1                   0            329
#                                        1             90
#                    2                   0             46
#                                        1             10
#                    3                   0             59
#                                        1              9
#                    4                   0             56
#                                        1              9
#                    5                   0             23
#                                        1             11
#                    6                   0             24
#                                        1             12
#                    7                   0             27
#                                        1              9
# ...

# %%
sns.catplot(y="NumCompaniesWorked",x="TotalWorkingYears",hue="Attrition",kind="violin",data=df)

# %% [markdown]
# #### Observation
# From the graph, we observed that
# - Employees worked in 1 or 2 company with 0-10 years experience have higher attrition rate.

# %%
df["YearsAtCompany"].plot.hist(grid=True, bins=20,rwidth=0.5,color='#607c8e')

# %%
sns.pairplot(data=df, x_vars=['Age','YearsAtCompany','MonthlyIncome'], y_vars='TotalWorkingYears', height=5, aspect=1, kind='reg')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-51-edb54238fc32> in <module>
# ----> 1 sns.pairplot(data=df, x_vars=['Age','YearsAtCompany','MonthlyIncome'], y_vars='TotalWorkingYears', height=5, aspect=1, kind='reg')
#
# C:\Ankita\Anaconda\lib\site-packages\seaborn\axisgrid.py in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, dropna, plot_kws, diag_kws, grid_kws, size)
#    2122     elif kind == "reg":
#    2123         from .regression import regplot  # Avoid circular import
# -> 2124         plotter(regplot, **plot_kws)
#    2125
#    2126     # Add a legend
#
# C:\Ankita\Anaconda\lib\site-packages\seaborn\axisgrid.py in map(self, func, **kwargs)
#    1339                     color = self.palette[k] if kw_color is None else kw_color
#    1340                     func(data_k[x_var], data_k[y_var],
# ...

# %%
sns.pairplot(df, vars=["Age","MonthlyIncome","TotalWorkingYears","YearsAtCompany","YearsInCurrentRole","YearsSinceLastPromotion"])
